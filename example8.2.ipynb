# %%
#same as last example but using implicit scheme

import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

# %%
def diffusion(nx,tf,dt,x):
    
    #given information about the rod
    
    rhoc=10*10**6    
    k=10
    L=.02

    dx=L/nx
    
    nt=tf/dt
    
    lambdax=(k*dt)/(rhoc*dx**2)
    
    
    T=numpy.zeros(nx) 
    T[:]=200
    TN=T.copy() #Temp distrubtion at time =0


    for i in range(int(nt)):
        TN=T.copy()

        T[1:-1]= lambdax * (T[2:] - 2 * T[1:-1] + T[0:-2] ) + TN[1:-1]

        #boundary conditions

        T[0] = lambdax * ( T[1] - T[0] ) + TN[0] 
        
        T[-1] = lambdax * (-3 * T[-1] + T[-2] ) + TN[-1]
        
        

    
    if x==1:
        print(T)
    X=numpy.linspace(0,.02,nx)
    plt.title(f"timestep {dt} s")
    plt.xlabel("Distance (m)")
    plt.ylabel("Temeperature (C)")
    plt.plot(X,T,label=dx)

plt.figure(figsize=(11,11),dpi=100)
diffusion(5,40,2,1)
diffusion(5,80,2,1)
diffusion(5,120,2,1)
legend=plt.legend(["40 s ","80 s ","120 s "])
legend.set_title("Time")
# Out:
# [186.51339636 175.2664859  147.31252207  99.5677212   34.65827816]
# [149.32301199 136.35417429 109.47939955  70.83532891  24.20608227]
# [115.86635265 105.37753375  84.06897654  54.06458263  18.4286018 ]

# %%
#for timestep of 8s

plt.figure(figsize=(11,11),dpi=100)
diffusion(5,40,8,1)
diffusion(5,80,8,1)
diffusion(5,120,8,1)
legend=plt.legend(["40 s ","80 s ","120 s "])
legend.set_title("Time")
# Out:
# [181.25    175.      134.375    95.3125   33.59375]
# [133.58459473 124.90844727 101.6998291   65.39154053  21.08230591]
# [97.85790443 91.55358076 74.1507858  47.76309282 15.5909203 ]
